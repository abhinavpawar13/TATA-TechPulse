# %% [markdown]
# # Tata Technologies Ltd. - TechPulse FY-26: Applied AI & ML
# ## Lab Statement 7: Pedestrian Detection using OpenCV
#
# **Curriculum Context:** Unit 3 – Deep Learning and Computer Vision (Object Detection Overview, OpenCV)
# **Track:** AI & ML | **Level:** Intermediate
# **Methodology:** Histogram of Oriented Gradients (HOG) + Linear Support Vector Machine (SVM)
# **Industrial Application:** Autonomous Emergency Braking (AEB), Forward Collision Warning, ADAS Pedestrian Safety
#
# ---
#
# ### 🎯 Learning Objectives
# 1. Compute spatial image gradients (Sobel filter), magnitude, and gradient orientation histograms.
# 2. Understand cell and block normalization mechanics in HOG feature extraction.
# 3. Deploy pre-trained Dalal-Triggs Linear SVM people detectors in OpenCV.
# 4. Implement Non-Maximum Suppression (NMS) to eliminate duplicate detection bounding boxes.
# 5. Evaluate detection precision, recall, and false positive rejection.
#
# ---

# %% [markdown]
# ### Step 0: Imports & Setup

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(f"OpenCV Version: {cv2.__version__}")

# %% [markdown]
# ### Step 1: Street Scene Ground Truth Annotations

# %%
annot_df = pd.read_csv('pedestrian_annotations.csv')
print(f"Pedestrians in Scene: {len(annot_df)}")
annot_df

# %% [markdown]
# ### Step 2: HOG Gradient Magnitude & Orientation Visualization

# %%
from IPython.display import Image
Image('plots/01_hog_gradient_magnitude_orientation.png')

# %% [markdown]
# ### Step 3: Raw Detections vs Non-Maximum Suppression (NMS)

# %%
Image('plots/02_pedestrian_detections_nms.png')

# %% [markdown]
# ### Step 4: Verification & Detection Performance Summary

# %%
Image('plots/03_detection_performance_summary.png')
