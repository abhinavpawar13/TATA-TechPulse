# %% [markdown]
# # Tata Technologies Ltd. - TechPulse FY-26: Applied AI & ML
# ## Lab Statement 9: Feature Importance Visualization
#
# **Curriculum Context:** Unit 4 – AI Fundamentals & Application Development (Feature Selection and Importance, XAI)
# **Track:** AI & ML | **Level:** Intermediate
# **Dataset:** Automotive Powertrain Fuel Efficiency Engineering Dataset (`automotive_features_dataset.csv`)
# **Domain Focus:** Explainable AI (XAI), Model Interpretability & Sensitivity Attribution
#
# ---
#
# ### 🎯 Learning Objectives
# 1. Calculate and interpret tree-based Mean Decrease in Impurity (MDI / Gini).
# 2. Evaluate out-of-sample Permutation Feature Importance (PFI) on holdout test partitions.
# 3. Generate Partial Dependence Plots (PDP) to uncover non-linear response curves.
# 4. Cross-compare MDI, Permutation, and Mutual Information frameworks.
#
# ---

# %% [markdown]
# ### Step 0: Imports & Environment Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.inspection import permutation_importance, PartialDependenceDisplay
from sklearn.feature_selection import mutual_info_regression

plt.style.use('seaborn-v0_8-whitegrid' if 'seaborn-v0_8-whitegrid' in plt.style.available else 'default')
plt.rcParams['figure.dpi'] = 120
print("Environment initialized!")

# %% [markdown]
# ### Step 1: Ingesting Automotive Engineering Attributes

# %%
df = pd.read_csv('automotive_features_dataset.csv')
print(f"Records: {len(df)} | Features: {df.shape[1]}")
df.head()

# %% [markdown]
# ### Step 2: Mean Decrease in Impurity (MDI) Importance

# %%
from IPython.display import Image
Image('plots/01_mdi_gini_feature_importance.png')

# %% [markdown]
# ### Step 3: Holdout Permutation Feature Importance (PFI)

# %%
Image('plots/02_permutation_importance_test_set.png')

# %% [markdown]
# ### Step 4: Partial Dependence Plots (PDP Non-Linear Response Curves)

# %%
Image('plots/03_partial_dependence_plots.png')

# %% [markdown]
# ### Step 5: Cross-Framework Feature Importance Comparison

# %%
Image('plots/04_feature_importance_methods_comparison.png')
