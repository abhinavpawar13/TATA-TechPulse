# %% [markdown]
# # Tata Technologies Ltd. - TechPulse FY-26: Applied AI & ML
# ## Lab Statement 6: Traffic Sign Classification using CNN
#
# **Curriculum Context:** Unit 3 – Deep Learning and Computer Vision (CNN Architecture, GTSRB Traffic Sign Recognition)
# **Track:** AI & ML | **Level:** Intermediate
# **Framework:** PyTorch, TorchVision / NumPy, Matplotlib
# **Industrial Application:** Advanced Driver Assistance Systems (ADAS), Speed Limit Detection, Camera Perception
#
# ---
#
# ### 🎯 Learning Objectives
# 1. Implement deep 2D Convolutional Neural Network architectures for image classification.
# 2. Utilize Batch Normalization, Max Pooling, and Dropout to prevent overfitting.
# 3. Train with Cross-Entropy Loss and the Adam optimizer on GTSRB-format canonical traffic signs.
# 4. Evaluate classification accuracy, confusion matrices, and test prediction confidence intervals.
#
# ---

# %% [markdown]
# ### Step 0: Imports & PyTorch Configuration

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(f"PyTorch Version: {torch.__version__} | CUDA Available: {torch.cuda.is_available()}")

# %% [markdown]
# ### Step 1: Ingesting Traffic Sign Metadata & Dataset Visualizations

# %%
meta_df = pd.read_csv('traffic_signs_metadata.csv')
print(f"Total Images: {len(meta_df)} | Classes: {meta_df['class_name'].nunique()}")
meta_df.head(10)

# %%
from IPython.display import Image
Image('plots/01_traffic_sign_samples_grid.png')

# %% [markdown]
# ### Step 2: CNN Architecture Definition & Forward Pass

# %%
class TrafficSignCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(TrafficSignCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )
        self.classifier = nn.Sequential(
            nn.Dropout(0.4),
            nn.Linear(128 * 4 * 4, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )
        
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

model = TrafficSignCNN(num_classes=10)
print(model)

# %% [markdown]
# ### Step 3: Training & Validation Loss Progression

# %%
Image('plots/02_cnn_training_loss_and_accuracy.png')

# %% [markdown]
# ### Step 4: Confusion Matrix Analysis

# %%
Image('plots/03_confusion_matrix_traffic_signs.png')

# %% [markdown]
# ### Step 5: Visual Inference Predictions with Confidence Percentages

# %%
Image('plots/04_sample_predictions_with_confidence.png')
