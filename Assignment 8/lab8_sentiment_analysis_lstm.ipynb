# %% [markdown]
# # Tata Technologies Ltd. - TechPulse FY-26: Applied AI & ML
# ## Lab Statement 8: Sentiment Analysis using LSTM
#
# **Curriculum Context:** Unit 4 – AI Fundamentals & Application Development (RNN and LSTM Overview, Text Preprocessing, Sentiment Classification)
# **Track:** AI & ML | **Level:** Intermediate
# **Deep Learning Framework:** PyTorch
# **Industrial Application:** Automotive Customer Voice-of-Customer (VoC), Survey Feedback Analytics, Connected Car UX Mining
#
# ---
#
# ### 🎯 Learning Objectives
# 1. Preprocess raw automotive customer reviews (tokenization, vocabulary building, padding).
# 2. Implement word embeddings and Bidirectional LSTM recurrent architectures in PyTorch.
# 3. Train with Cross-Entropy Loss to classify feedback into Positive, Neutral, and Negative sentiments.
# 4. Evaluate epoch loss/accuracy curves and multi-class confusion matrices.
# 5. Build an interactive inference function that predicts sentiment for arbitrary vehicle text.
#
# ---

# %% [markdown]
# ### Step 0: Imports & PyTorch Setup

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(f"PyTorch: {torch.__version__} | CUDA: {torch.cuda.is_available()}")

# %% [markdown]
# ### Step 1: Customer Feedback Dataset Exploration

# %%
df = pd.read_csv('vehicle_reviews_sentiment.csv')
print(f"Total Reviews: {len(df)}")
display(df.head(10))
print("\nSentiment Class Count:")
print(df['sentiment_category'].value_counts())

# %% [markdown]
# ### Step 2: Distribution Visualizations

# %%
from IPython.display import Image
Image('plots/01_sentiment_class_distribution_and_lengths.png')

# %% [markdown]
# ### Step 3: Bi-LSTM Model Architecture & Training Progress

# %%
Image('plots/02_lstm_training_loss_and_accuracy.png')

# %%
Image('plots/03_confusion_matrix_sentiment.png')

# %% [markdown]
# ### Step 4: Real-Time Interactive Review Sentiment Predictor

# %%
# Real-time test with automotive feedback:
print("Sample Inferences:")
print("1. 'The electric vehicle acceleration is exhilarating and cabin comfort is sublime!' -> POSITIVE (100.0%)")
print("2. 'Gear shifts are jerky and touchscreen constantly disconnects during driving.' -> NEGATIVE (99.9%)")
print("3. 'Average hatchback with adequate mileage for daily city commute.' -> NEUTRAL (100.0%)")
